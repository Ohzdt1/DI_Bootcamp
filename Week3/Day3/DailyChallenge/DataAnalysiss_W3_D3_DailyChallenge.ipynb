# %%
# !pip install kaggle

from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle competitions download -c Data Science Job Salary dataset
# Out:
# ...
#      <input type="file" id="files-209828ae-c7d7-4b10-91b2-d34d7a9cb752" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-209828ae-c7d7-4b10-91b2-d34d7a9cb752">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip Data_Science_Job_Salary_dataset.zip
# Out:
# Archive:  Data_Science_Job_Salary_dataset.zip
#   inflating: Data Science Job Salary dataset/datascience_salaries.csv

# %%
import pandas as pd

DSJS_data = pd.read_csv('datascience_salaries.csv')

# Explore the dataset
print(DSJS_data.head())
print(DSJS_data.info())
DSJS_data.describe()
# Out:
#    Unnamed: 0       job_title   job_type experience_level       location  \
# 0           0  Data scientist  Full Time           Senior  New York City
# 1           2  Data scientist  Full Time           Senior         Boston
# 2           3  Data scientist  Full Time           Senior         London
# 3           4  Data scientist  Full Time           Senior         Boston
# 4           5  Data scientist  Full Time           Senior  New York City
#
#   salary_currency  salary
# 0             USD  149000
# 1             USD  120000
# 2             USD   68000
# 3             USD  120000
# 4             USD  149000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171 entries, 0 to 1170
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1171 non-null   int64
#  1   job_title         1171 non-null   object
#  2   job_type          1171 non-null   object
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
DSJS_data['salary'] = scaler.fit_transform(DSJS_data[['salary']])

DSJS_data.head()
# Out:
#    Unnamed: 0       job_title   job_type experience_level       location  \
# 0           0  Data scientist  Full Time           Senior  New York City
# 1           2  Data scientist  Full Time           Senior         Boston
# 2           3  Data scientist  Full Time           Senior         London
# 3           4  Data scientist  Full Time           Senior         Boston
# 4           5  Data scientist  Full Time           Senior  New York City
#
#   salary_currency    salary
# 0             USD  0.601010
# 1             USD  0.454545
# 2             USD  0.191919
# 3             USD  0.454545
# 4             USD  0.601010

# %%
print(DSJS_data.dtypes)
# Out:
# Unnamed: 0            int64
# job_title            object
# job_type             object
# experience_level     object
# location             object
# salary_currency      object
# salary              float64
# dtype: object

# %%
pca = PCA(n_components=2)
pca_components = pca.fit_transform(DSJS_data_encoded.select_dtypes(include=['float64', 'int64']))

DSJS_data_encoded['PCA1'] = pca_components[:, 0]
DSJS_data_encoded['PCA2'] = pca_components[:, 1]

DSJS_data_encoded.head()
# Out:
#    Unnamed: 0    salary  job_title_Data analyst  job_title_Data scientist  \
# 0           0  0.601010                   False                      True
# 1           2  0.454545                   False                      True
# 2           3  0.191919                   False                      True
# 3           4  0.454545                   False                      True
# 4           5  0.601010                   False                      True
#
#    job_title_ML Ops  job_title_Machine learning  job_type_Internship  \
# 0             False                       False                False
# 1             False                       False                False
# 2             False                       False                False
# 3             False                       False                False
# 4             False                       False                False
#
#    experience_level_Executive  experience_level_Mid  experience_level_Senior  \
# ...

# %%
salary_aggregates = DSJS_data.groupby('experience_level')['salary'].agg(['mean', 'median'])

salary_aggregates.rename(columns={'mean': 'Average_Salary', 'median': 'Median_Salary'}, inplace=True)

print(salary_aggregates)
# Out:
#                   Average_Salary  Median_Salary
# experience_level
# Entry                   0.030864       0.000000
# Executive               0.232712       0.080808
# Mid                     0.110035       0.106061
# Senior                  0.227717       0.191919
