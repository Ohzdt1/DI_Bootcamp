# %% [markdown]
# # **Matplotlib Charts**

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, color='green', linestyle='dashed', linewidth=2, marker='o', markerfacecolor='blue', markersize=12)
plt.show()

# %%
categories = ['Apples', 'Bananas', 'Oranges', 'Grapes']
values = [20, 35, 30, 15]

plt.bar(categories, values)
plt.title('Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %%
plt.bar(categories, values, color=['red', 'green', 'blue', 'purple'], edgecolor='black', hatch='/')
plt.title('Customized Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %%
categories = ['Apples', 'Bananas', 'Oranges', 'Grapes']
values = [20, 35, 30, 15]

plt.bar(categories, values, color = ['magenta', 'green', 'blue', 'purple'])
plt.title('Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %%
import numpy as np

data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=30, edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
import numpy as np

data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=50, density=True, alpha=0.3, edgecolor='black', color='w')
counts, bin_edges, _ = plt.hist(data, bins=20, color='blue', alpha=0.6)
plt.plot(bin_edges[:-1], counts, marker='o', color='red', linestyle='-')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
brands = ['Apple', 'Samsung', 'Huawei', 'Xiaomi', 'Others']
market_share = [40, 30, 15, 10, 5]

plt.pie(market_share, labels=brands, autopct='%1.1f%%')
plt.title('Smartphone Market Share 2023')
plt.show()

# %%
explode = (0.1, 0.1, 0.2, 0.3, 0)
plt.pie(market_share, labels=brands, autopct='%1.1f%%', explode=explode)
plt.show()

# %%
import numpy as np

data = np.random.randn(100)
plt.boxplot(data)
plt.title('Basic Box Plot')
plt.ylabel('Values')
plt.show()

# %%
data
# Out:
# array([ 0.25190136,  0.27986925, -0.2811984 , -1.9184766 , -0.32009772,
#        -1.0146971 ,  0.08274203, -0.13133783, -0.28930558, -0.19342556,
#        -1.54621067,  1.51248397,  0.29481341, -0.3788801 , -1.08500831,
#         1.40795884, -0.98820329,  0.56901647,  0.67880863, -0.03210758,
#         0.24089466, -0.30023914,  0.25280353,  1.26563217, -1.17655157,
#         1.39605782, -1.00515543,  1.52136794, -0.32344928,  0.7977388 ,
#         0.86612923, -1.02434106,  1.68689806,  0.28635733,  0.34793694,
#        -0.34709311, -0.55666803,  0.15425518, -1.14073133, -0.48980114,
#        -0.80612806, -1.34354181,  0.57880227, -0.31204428, -0.24036322,
#         1.5882693 , -0.56815939, -0.1705211 , -0.27975491, -0.7414373 ,
#         0.94985822,  0.44261357, -0.14432224,  1.30100684, -1.47189733,
#        -1.7815287 ,  0.387543  , -1.45914603, -0.16139555, -0.68373601,
#         0.6446986 , -0.37167831,  0.62147731,  0.12688935,  0.78693787,
#        -0.36432737, -1.90653253, -0.44227061,  1.26877652, -0.81017952,
#        -0.84052296,  0.74497194,  2.51728818,  1.00403764, -1.49132049,
#         0.25266167,  0.79300569, -2.1748447 ,  2.57499075,  1.2895488 ,
#         1.76282118, -0.45330228, -0.15078495, -1.03959157, -2.91474453,
#        -1.11753558,  2.28162539,  0.80533307,  1.14812065, -1.44648041,
#        -0.19308005, -0.74241827, -0.30187688, -0.34201146,  0.70904169,
#         1.02524248,  0.39658986,  0.40455823,  0.57531315, -0.06440427])

# %%
x = np.linspace(0, 10)
y = x**2

plt.title('Just a Line')
plt.xlabel('sideways')
plt.ylabel('upwards')

plt.scatter(x, y)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot([1, 2, 3], [1, 4, 9])
ax1.set_title('First Subplot')

ax2.plot([1, 2, 3], [1, 2, 3])
ax2.set_title('Second Subplot')

plt.show()

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(9, 8))  # Adjust figure size

ax1.plot([1, 2, 3], [1, 4, 9])
ax1.set_title('First Subplot')

ax2.plot([1, 2, 3], [1, 2, 3])
ax2.set_title('Second Subplot')

plt.subplots_adjust(hspace=0.5)  # Adjust vertical spacing between subplots

plt.show()

# %% [markdown]
# ## **Hands-On Exercises**

# %%
x = np.linspace(0, 10)
y = x**2

plt.title('Just a Line')
plt.xlabel('sideways')
plt.ylabel('upwards')

plt.plot(x, y)
plt.show()

# %%
categories = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']
values = [20, 35, 30, 15, 20]

plt.bar(categories, values, color=['red', 'green', 'blue', 'purple','yellow'], edgecolor='black', hatch='/')
plt.title('Sales of 5 Things')
plt.xlabel('Quant')
plt.ylabel('Sales')
plt.show()

# %%
data = np.random.normal(0, 1, 500)
plt.hist(data, bins=100, color = 'purple', edgecolor='y', alpha = 0.9)
plt.title("Histogram of 500 Normally Distributed Points Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
daily_activities = ['working', 'chores','learning', 'sleeping', 'gaming', 'exercise']
time_quant = [9.5, 3, 7, 3, 0.1, 0.1]

plt.pie(time_quant, labels=daily_activities, autopct='%1.1f%%')
plt.title('Time Spent on Different Daily Activities')
plt.show()

# %% [markdown]
# # **Seaborn**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample data
data = sns.load_dataset('tips')
sns.histplot(data['total_bill'], bins=20, color='skyblue')
plt.title('Histogram of Total Bill')
plt.show()

# %%
sns.kdeplot(data['total_bill'], shade=True, color='purple')
plt.title('KDE of Total Bill')
plt.show()
# Out:
# <ipython-input-89-c50108c949cc>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['total_bill'], shade=True, color='purple')

# %%
sns.jointplot(x='total_bill', y='tip', data=data, kind='scatter', color='green')
plt.show()

# %%
titanic = sns.load_dataset('titanic')
sns.barplot(x='class', y='survived', data=titanic, palette='Blues')
plt.title('Survival Rate by Class')
plt.show()
# Out:
# <ipython-input-91-24a7d9d81cac>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='class', y='survived', data=titanic, palette='Blues')

# %%
sns.boxplot(x='class', y='age', data=titanic, palette='Set3')
plt.title('Age Distribution by Class')
plt.show()
# Out:
# <ipython-input-92-6c977577a5c9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='age', data=titanic, palette='Set3')

# %%
sns.violinplot(x='class', y='age', data=titanic, palette='muted')
plt.title('Age Distribution by Class')
plt.show()
# Out:
# <ipython-input-93-ba8ad66e93f4>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='class', y='age', data=titanic, palette='muted')

# %%
sns.lmplot(x='total_bill', y='tip', data=data, aspect=1.5, height=5)
plt.title('Scatter Plot with Regression Line')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data=data, kind='reg', color='orange')
plt.show()

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species', palette='Dark2')
plt.show()

# %%
correlation_matrix = iris.select_dtypes(include=np.number).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()


# correlation_matrix = iris.corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# plt.title('Correlation Matrix Heatmap')
# plt.show()

# %%
data = sns.load_dataset('tips')
g = sns.FacetGrid(data, col='time', row='smoker', margin_titles=True)
g.map(sns.scatterplot, 'total_bill', 'tip', color='red')
plt.show()

# %%
iris = sns.load_dataset('iris')
g = sns.PairGrid(iris, hue='species')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, cmap='Blues')
g.map_diag(sns.histplot, kde=True, color='teal')
g.add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_context('talk')
sns.set_style('whitegrid')
sns.histplot(data['total_bill'], color='darkblue', bins=15)
plt.title('Advanced Aesthetic Customization')
plt.show()

# %% [markdown]
# # **Hands-On Exercises**

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data = sns.load_dataset('tips')
sns.histplot(data['total_bill'], bins=100, color='purple')
plt.title('Histogram of Customer Spending')
plt.show()
