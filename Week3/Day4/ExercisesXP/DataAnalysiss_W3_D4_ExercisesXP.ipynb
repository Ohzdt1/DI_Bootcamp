# %% [markdown]
# # **🌟 Exercise 1: Understanding Data Visualization**
#
#
# Task 1: Explain why data visualization is important in data analysis.
#
# Enhances Understanding – We process visual information faster than raw numbers. Visualizing data helps in identifying trends, patterns, and anomalies.
#
# Simplifies Complex Data – Large datasets can be difficult to interpret in raw form. Charts, graphs, and plots make it easier to summarize and communicate insights effectively.
#
# Supports Decision Making – Visualization provides a clear representation of data that helps stakeholders and decision-makers draw conclusions and make informed choices without getting lost in details that dont necessarily matter.
#
# Detects Patterns & Trends – Helps in identifying relationships, trends over time, and outliers that might indicate errors or areas of interest.
#
# Communicates Insights Effectively – A well-designed visualization can tell a story and make data more accessible to non-technical audiences.
#
#
# Task 2: Describe the purpose of a line graph in data visualization.
#
# A line graph is used to Show trends over time.
#
# Display continuous data, where one data point naturally connects to the next.
#
# Compare multiple data series by plotting multiple lines on the same graph.This will help identify patterns, fluctuations, and anomalies in data over a period.

# %% [markdown]
# # **🌟 Exercise 2: Creating a Line Plot for Temperature Variation**

# %%
import matplotlib.pyplot as plt

# Define data
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
temperatures = [72, 74, 76, 80, 82, 78, 75]

print(days)
print(temperatures)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# [72, 74, 76, 80, 82, 78, 75]

# %%
# Create the plot
plt.plot(days, temperatures, marker='o', linestyle='-', color='b', label="Temperature")

plt.xlabel("Day")
plt.ylabel("Temperature (°F)")
plt.title("Temperature Variation Over a Week")
plt.legend()

plt.show()

# %% [markdown]
# # **🌟 Exercise 3: Visualizing Monthly Sales with a Bar Chart**

# %%
import matplotlib.pyplot as plt

# %%
# Define data
months = ["January", "February", "March", "April", "May"]
sales = [5000, 5500, 6200, 7000, 7500]

print(months)
print(sales)
# Out:
# ['January', 'February', 'March', 'April', 'May']
# [5000, 5500, 6200, 7000, 7500]

# %%
# Create the bar chart
plt.bar(months, sales, color='green')

plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")
plt.title("Monthly Sales Data")

plt.show()

# %% [markdown]
# # **🌟 Exercise 4: Visualizing the Distribution of CGPA with a Histogram**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Sample CGPA data
data = {"CGPA": [2.5, 3.0, 3.2, 3.5, 3.7, 3.8, 3.9, 4.0, 2.8, 3.6, 3.3, 2.9, 3.4, 3.1, 3.0]}
df = pd.DataFrame(data)

print(data)
print(df)
# Out:
# {'CGPA': [2.5, 3.0, 3.2, 3.5, 3.7, 3.8, 3.9, 4.0, 2.8, 3.6, 3.3, 2.9, 3.4, 3.1, 3.0]}
#     CGPA
# 0    2.5
# 1    3.0
# 2    3.2
# 3    3.5
# 4    3.7
# 5    3.8
# 6    3.9
# 7    4.0
# 8    2.8
# 9    3.6
# 10   3.3
# 11   2.9
# 12   3.4
# 13   3.1
# 14   3.0

# %%
# Create the histogram
sns.histplot(df["CGPA"], bins=14, kde=True, color='purple')

# Add labels and title
plt.xlabel("CGPA")
plt.ylabel("Frequency")
plt.title("Distribution of CGPA")

# Display the plot
plt.show()

# %% [markdown]
# # **🌟 Exercise 5: Comparing Anxiety Levels Across Different Genders**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Sample data
data = {
    "Gender": ["Male", "Female", "Female", "Male", "Male", "Female", "Female", "Male", "Male", "Female"],
    "Anxiety": ["Yes", "No", "Yes", "Yes", "No", "No", "Yes", "Yes", "Yes", "No"]
}

# Create DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#    Gender Anxiety
# 0    Male     Yes
# 1  Female      No
# 2  Female     Yes
# 3    Male     Yes
# 4    Male      No
# 5  Female      No
# 6  Female     Yes
# 7    Male     Yes
# 8    Male     Yes
# 9  Female      No

# %%
# Create the bar plot
sns.countplot(x="Gender", hue="Anxiety", data=df, palette="Set1")

# Add labels and title
plt.xlabel("Gender")
plt.ylabel("Count of Students")
plt.title("Anxiety Levels Across Different Genders")

# Display the plot
plt.show()

# %% [markdown]
# # **🌟 Exercise 6: Exploring the Relationship Between Age and Panic Attacks**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Sample data
data = {
    "Age": [18, 20, 22, 19, 21, 23, 18, 25, 24, 22],
    "Panic_Attacks": ["Yes", "No", "Yes", "No", "Yes", "No", "Yes", "Yes", "No", "Yes"]
}

# Create DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#    Age Panic_Attacks
# 0   18           Yes
# 1   20            No
# 2   22           Yes
# 3   19            No
# 4   21           Yes
# 5   23            No
# 6   18           Yes
# 7   25           Yes
# 8   24            No
# 9   22           Yes

# %%
# Convert Panic_Attacks to numeric values
df["Panic_Attacks"] = df["Panic_Attacks"].map({"Yes": 1, "No": 0})

print(df)
# Out:
#    Age  Panic_Attacks
# 0   18              1
# 1   20              0
# 2   22              1
# 3   19              0
# 4   21              1
# 5   23              0
# 6   18              1
# 7   25              1
# 8   24              0
# 9   22              1

# %%
# Create the scatter plot
sns.scatterplot(x="Age", y="Panic_Attacks", data=df, hue="Panic_Attacks", palette="bright", s=100)

# Add labels and title
plt.xlabel("Age")
plt.ylabel("Panic Attacks (1 = Yes, 0 = No)")
plt.title("Relationship Between Age and Panic Attacks")

# Display the plot
plt.show()
